# %%
#I used the following general methodology for analysis / prediction:

    #Imported CSV and converted to data frame
    #Performed exploratory data analysis
    #Cleansed data
    #Random Forest Classifier algorithm
 
# The model selects a sample of claimants from the original dataset and predicts opiod use each time the script is run
# The script generates the output in a .csv file "opiodusepredictionresults.csv"
#I have used a random forrest classifier model to predict opiod use by claimants

# %%
#import libraries

#Multidimensional Array and Matrix Representation Library needed to input cleansed data into model
import numpy as np 

# Python Data Analysis Library for Data Frame, CSV File I/O 
import pandas as pd 

#Data Visualization Library
# %matplotlib inline
import matplotlib.pyplot as plt

#Data Visualization Library built on top of Matplotlib
#a cleaner visualization and easier interface to call
import seaborn as sns


#Algorithms and accuracy testing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import export_graphviz

# %%
#DATA IMPORT, INSPECTION AND CLEANSING


#i'm going to standardize any missing values in 
#our data frame so that all missing values are picked up i.e. n/a, na, Naan 
missing_values = ["n/a", "na", "--"]

#import file and define as maindf, i've renamed the original file to 'train.csv' 
#for ease of use. This will be the file that will train the model
maindf = pd.read_csv('train.csv',low_memory=False, na_values = missing_values)

# %%
#inspect the data by looking at the top 5 rows
maindf.head()
# Out:
#    ClaimID  Accident DateID  Claim Setup DateID  Report To GB DateID  \
# 0     7275          33460.0               33467                33462
# 1    17596              NaN               34301                34300
# 2    13834          35043.0               35054                35050
# 3     5719          33136.0               33147                33145
# 4     8646          33262.0               33277                33264
#
#    Employer Notification DateID Benefits State Accident State  Industry ID  \
# 0                       33460.0             OK             OK           17
# 1                       34270.0             CO            NaN           17
# 2                       35043.0             MD             MD           17
# 3                       33136.0             IL             IL            9
# 4                       33264.0             IL             IL            9
#
#    Claimant Age Claimant Sex  ... CPT Category - Eval_Mgmt  \
# 0            41            M  ...                        7
# 1            49            M  ...                        4
# 2            47            M  ...                        4
# 3            35            F  ...                        2
# 4            30            F  ...                        2
#
#   CPT Category - Medicine  CPT Category - Path_Lab  CPT Category - Radiology  \
# 0                       1                        3                         5
# 1                      12                        1                         4
# 2                       1                        0                         0
# 3                       1                        0                         2
# 4                       4                        0                         6
#
#   CPT Category - Surgery NDC Class - Benzo  NDC Class - Misc (Zolpidem)  \
# 0                      1                 0                            0
# 1                      9                 0                            0
# 2                      2                 0                            0
# 3                      0                 0                            0
# 4                      0                 0                            0
#
#    NDC Class - Muscle Relaxants  NDC Class - Stimulants Opiods Used
# 0                             0                       0       False
# 1                             0                       0        True
# 2                             0                       0       False
# 3                             1                       0       False
# 4                             0                       0       False
#
# [5 rows x 92 columns]

# %%
#inspect the data by looking at the bottome 5 rows
maindf.tail()
# Out:
#         ClaimID  Accident DateID  Claim Setup DateID  Report To GB DateID  \
# 160611   182862          33473.0               33475                33473
# 160612   198379          34793.0               34801                34795
# 160613   182403              NaN               34902                34901
# 160614   190166          33757.0               33761                33760
# 160615   182604          33915.0               33915                33915
#
#         Employer Notification DateID Benefits State Accident State  \
# 160611                       33473.0             PA             PA
# 160612                       34793.0             PA             PA
# 160613                       34901.0             PA            NaN
# 160614                       33759.0             AZ             AZ
# 160615                       33915.0             NJ             NJ
#
#         Industry ID  Claimant Age Claimant Sex  ... CPT Category - Eval_Mgmt  \
# 160611           12            50            M  ...                        3
# 160612            7            52            F  ...                        4
# 160613           16            22            M  ...                       10
# 160614            7            60            F  ...                        4
# 160615            7            50            F  ...                        3
#
#        CPT Category - Medicine  CPT Category - Path_Lab  \
# 160611                       9                        1
# 160612                       7                        0
# 160613                      21                        6
# 160614                       6                        0
# 160615                       3                        0
#
#         CPT Category - Radiology CPT Category - Surgery NDC Class - Benzo  \
# 160611                         4                      1                 0
# 160612                         4                      1                 0
# 160613                         5                      4                 0
# 160614                         0                      0                 0
# 160615                         0                      1                 0
#
#         NDC Class - Misc (Zolpidem)  NDC Class - Muscle Relaxants  \
# 160611                            0                             0
# 160612                            0                             0
# 160613                            0                             0
# 160614                            0                             1
# 160615                            0                             0
#
#         NDC Class - Stimulants Opiods Used
# 160611                       0       False
# 160612                       0       False
# 160613                       0        True
# 160614                       0       False
# 160615                       0       False
#
# [5 rows x 92 columns]

# %%
# statistical description of numerical columns
maindf.describe()
# Out:
#              ClaimID  Accident DateID  Claim Setup DateID  \
# count  160616.000000    144713.000000       160616.000000
# mean   499642.652426     34158.445350        34220.719897
# std    288365.183875       649.503895          660.237952
# min         7.000000     33064.000000        33067.000000
# 25%    249379.750000     33602.000000        33656.000000
# 50%    499038.500000     34137.000000        34214.000000
# 75%    749653.250000     34686.000000        34761.000000
# max    999999.000000     35592.000000        35601.000000
#
#        Report To GB DateID  Employer Notification DateID    Industry ID  \
# count        160616.000000                 160615.000000  160616.000000
# mean          34215.138230                  34207.019170      11.618905
# std             660.180925                    661.044586       4.321883
# min           33066.000000                  28932.000000       0.000000
# 25%           33650.000000                  33642.000000       8.000000
# 50%           34208.000000                  34198.000000      13.000000
# 75%           34755.000000                  34748.000000      15.000000
# max           35594.000000                  35593.000000      20.000000
#
#         Claimant Age  Number Dependents    Weekly Wage  \
# count  160616.000000      160616.000000  160616.000000
# mean       42.814533           0.427573     709.457650
# std        13.176824           1.027837     487.976345
# min         0.000000           0.000000       0.000000
# 25%        32.000000           0.000000     385.065000
# 50%        44.000000           0.000000     595.075000
# 75%        53.000000           0.000000     946.275000
# max       113.000000          15.000000    9999.990000
#
#        Max Medical Improvement DateID  ...  CPT Category - Anesthesia  \
# count                    72580.000000  ...              160616.000000
# mean                     34396.177804  ...                   0.318026
# std                        638.807697  ...                   0.698940
# min                      33066.000000  ...                   0.000000
# 25%                      33873.000000  ...                   0.000000
# 50%                      34405.000000  ...                   0.000000
# 75%                      34928.000000  ...                   1.000000
# max                      35658.000000  ...                  34.000000
#
#        CPT Category - Eval_Mgmt  CPT Category - Medicine  \
# count             160616.000000            160616.000000
# mean                   3.752615                 5.819557
# std                    2.461367                 6.055342
# min                    0.000000                 0.000000
# 25%                    2.000000                 1.000000
# 50%                    3.000000                 5.000000
# 75%                    5.000000                 8.000000
# max                   31.000000                92.000000
#
#        CPT Category - Path_Lab  CPT Category - Radiology  \
# count            160616.000000             160616.000000
# mean                  1.765465                  2.408558
# std                   5.241317                  2.730262
# min                   0.000000                  0.000000
# 25%                   0.000000                  1.000000
# 50%                   0.000000                  2.000000
# 75%                   1.000000                  3.000000
# max                 112.000000                 61.000000
#
#        CPT Category - Surgery  NDC Class - Benzo  NDC Class - Misc (Zolpidem)  \
# count           160616.000000      160616.000000                160616.000000
# mean                 1.684135           0.007023                     0.009999
# std                  2.736504           0.111368                     0.119508
# min                  0.000000           0.000000                     0.000000
# 25%                  0.000000           0.000000                     0.000000
# 50%                  1.000000           0.000000                     0.000000
# 75%                  2.000000           0.000000                     0.000000
# max                 75.000000           9.000000                     5.000000
#
#        NDC Class - Muscle Relaxants  NDC Class - Stimulants
# count                 160616.000000           160616.000000
# mean                       0.194426                0.000286
# std                        0.597437                0.022316
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                       13.000000                3.000000
#
# [8 rows x 71 columns]

# %%
# statistical description of non-numerical columns
maindf.describe(include=['object'])
# Out:
#        Benefits State Accident State Claimant Sex Claimant State  \
# count          160616         144713       160616         160300
# unique             52             61            4             60
# top                CA             CA            M             CA
# freq            28252          24138        96719          28277
#
#        Claimant Marital Status Employment Status Flag RTW Restriction Flag  \
# count                   160616                 160616               160616
# unique                       5                     14                    4
# top                          S                      F                    N
# freq                     64414                 134555                86423
#
#        NCCI Job Code Disability Status          SIC Group  \
# count         160616            139547             160616
# unique          1281                 4                 51
# top             8810               TTD  Business Services
# freq            5680            103272              14373
#
#        NCCI BINatureOfLossDescription Accident Type Group
# count                          146190              150107
# unique                             15                  16
# top                            Strain              ATCgr6
# freq                            56071               62080

# %%
#review the data element types and empty values
maindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160616 entries, 0 to 160615
# Data columns (total 92 columns):
# ClaimID                            160616 non-null int64
# Accident DateID                    144713 non-null float64
# Claim Setup DateID                 160616 non-null int64
# Report To GB DateID                160616 non-null int64
# Employer Notification DateID       160615 non-null float64
# Benefits State                     160616 non-null object
# Accident State                     144713 non-null object
# Industry ID                        160616 non-null int64
# Claimant Age                       160616 non-null int64
# Claimant Sex                       160616 non-null object
# Claimant State                     160300 non-null object
# Claimant Marital Status            160616 non-null object
# Number Dependents                  160616 non-null int64
# Weekly Wage                        160616 non-null float64
# Employment Status Flag             160616 non-null object
# RTW Restriction Flag               160616 non-null object
# Max Medical Improvement DateID     72580 non-null float64
# Percent Impairment                 160616 non-null int64
# Post Injury Weekly Wage            160616 non-null float64
# NCCI Job Code                      160616 non-null object
# Surgery Flag                       160616 non-null int64
# Disability Status                  139547 non-null object
# SIC Group                          160616 non-null object
# NCCI BINatureOfLossDescription     146190 non-null object
# Accident Source Code               71585 non-null float64
# Accident Type Group                150107 non-null object
# Neurology Payment Flag             160616 non-null bool
# Neurosurgery Payment Flag          160616 non-null bool
# Dentist Payment Flag               160616 non-null bool
# Orthopedic Surgery Payment Flag    160616 non-null bool
# Psychiatry Payment Flag            160616 non-null bool
# Hand Surgery Payment Flag          160616 non-null bool
# Optometrist Payment Flag           160616 non-null bool
# Podiatry Payment Flag              160616 non-null bool
# HCPCS A Codes                      160616 non-null int64
# HCPCS B Codes                      160616 non-null int64
# HCPCS C Codes                      160616 non-null int64
# HCPCS D Codes                      160616 non-null int64
# HCPCS E Codes                      160616 non-null int64
# HCPCS F Codes                      160616 non-null int64
# HCPCS G Codes                      160616 non-null int64
# HCPCS H Codes                      160616 non-null int64
# HCPCS I Codes                      160616 non-null int64
# HCPCS J Codes                      160616 non-null int64
# HCPCS K Codes                      160616 non-null int64
# HCPCS L Codes                      160616 non-null int64
# HCPCS M Codes                      160616 non-null int64
# HCPCS N Codes                      160616 non-null int64
# HCPCS O Codes                      160616 non-null int64
# HCPCS P Codes                      160616 non-null int64
# HCPCS Q Codes                      160616 non-null int64
# HCPCS R Codes                      160616 non-null int64
# HCPCS S Codes                      160616 non-null int64
# HCPCS T Codes                      160616 non-null int64
# HCPCS U Codes                      160616 non-null int64
# HCPCS V Codes                      160616 non-null int64
# HCPCS W Codes                      160616 non-null int64
# HCPCS X Codes                      160616 non-null int64
# HCPCS Y Codes                      160616 non-null int64
# HCPCS Z Codes                      160616 non-null int64
# ICD Group 1                        160616 non-null int64
# ICD Group 2                        160616 non-null int64
# ICD Group 3                        160616 non-null int64
# ICD Group 4                        160616 non-null int64
# ICD Group 5                        160616 non-null int64
# ICD Group 6                        160616 non-null int64
# ICD Group 7                        160616 non-null int64
# ICD Group 8                        160616 non-null int64
# ICD Group 9                        160616 non-null int64
# ICD Group 10                       160616 non-null int64
# ICD Group 11                       160616 non-null int64
# ICD Group 12                       160616 non-null int64
# ICD Group 13                       160616 non-null int64
# ICD Group 14                       160616 non-null int64
# ICD Group 15                       160616 non-null int64
# ICD Group 16                       160616 non-null int64
# ICD Group 17                       160616 non-null int64
# ICD Group 18                       160616 non-null int64
# ICD Group 19                       160616 non-null int64
# ICD Group 20                       160616 non-null int64
# ICD Group 21                       160616 non-null int64
# CPT Category - Anesthesia          160616 non-null int64
# CPT Category - Eval_Mgmt           160616 non-null int64
# CPT Category - Medicine            160616 non-null int64
# CPT Category - Path_Lab            160616 non-null int64
# CPT Category - Radiology           160616 non-null int64
# CPT Category - Surgery             160616 non-null int64
# NDC Class - Benzo                  160616 non-null int64
# NDC Class - Misc (Zolpidem)        160616 non-null int64
# NDC Class - Muscle Relaxants       160616 non-null int64
# NDC Class - Stimulants             160616 non-null int64
# Opiods Used                        160616 non-null bool
# dtypes: bool(9), float64(6), int64(65), object(12)
# memory usage: 95.7+ MB

# %%
#missing data in the following

#Accident DateID	144713	non-null	float64
#Employer Notification DateID	160615	non-null	float64
#Accident State	144713	non-null	object
#Claimant State	160300	non-null	object
#Max Medical Improvement DateID	72580	non-null	float64
#Disability Status	139547	non-null	object
#NCCI BINatureOfLossDescription	146190	non-null	object
#Accident Source Code	71585	non-null	float64
#Accident Type Group	150107	non-null	object

#I would typically clean the missing data (and fill in with median as an example)but have not in this excersise
#due to time constraints

# %%
#lets inspect the floats
flt_df = maindf.select_dtypes(include=['float']).copy()
flt_df.head()
# Out:
#    Accident DateID  Employer Notification DateID  Weekly Wage  \
# 0          33460.0                       33460.0       513.86
# 1              NaN                       34270.0      1186.00
# 2          35043.0                       35043.0       851.69
# 3          33136.0                       33136.0       300.00
# 4          33262.0                       33264.0       600.00
#
#    Max Medical Improvement DateID  Post Injury Weekly Wage  \
# 0                             NaN                      0.0
# 1                         34726.0                      0.0
# 2                         35051.0                      0.0
# 3                             NaN                      0.0
# 4                             NaN                      0.0
#
#    Accident Source Code
# 0                   NaN
# 1                6314.0
# 2                   NaN
# 3                7726.0
# 4                   NaN

# %%
#lets inspect the objects
obj_df = maindf.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   Benefits State Accident State Claimant Sex Claimant State  \
# 0             OK             OK            M             OK
# 1             CO            NaN            M             CO
# 2             MD             MD            M             VA
# 3             IL             IL            F             IL
# 4             IL             IL            F             WI
#
#   Claimant Marital Status Employment Status Flag RTW Restriction Flag  \
# 0                       M                      F                    Y
# 1                       M                      F                    N
# 2                       U                      F                    N
# 3                       M                      P                    N
# 4                       M                      F
#
#   NCCI Job Code Disability Status          SIC Group  \
# 0          5040               TTD         Gen. cont.
# 1          5190               PPD         Gen. cont.
# 2          5183               TTD         Gen. cont.
# 3          8868               TTD  Misc. Manuf. Ind.
# 4          8868               TTD  Misc. Manuf. Ind.
#
#   NCCI BINatureOfLossDescription Accident Type Group
# 0                         Strain              ATCgr7
# 1                   Inflammation              ATCgr6
# 2                   Foreign Body                 NaN
# 3                         Strain              ATCgr6
# 4                     Contusions              ATCgr1

# %%
# in the interest of time, i'm going to drop the floating and object variables from the df as we would
# need to convert the float to numeric and then one hot encode the numeric values 
#to remove any numerical bias in the model 
#if we were to improve the model we would work on filling empty data
#and transforming the floating to numerical catagories then possibly one hot encoding using

# %%
#while the floating, object and numerical data elements can be cleansed, 
#in the interest of time lets just focus on the boolean catagories for now as they look clean and complete
#lets create a new data frame and name it 'cleandf' with all floating and numeric variables removed

cleandf = maindf.drop(['Accident DateID',
'Claim Setup DateID',
'Report To GB DateID',
'Employer Notification DateID',
'Benefits State',
'Accident State',
'Industry ID',
'Claimant Age',
'Claimant Sex',
'Claimant State',
'Claimant Marital Status',
'Number Dependents',
'Weekly Wage',
'Employment Status Flag',
'RTW Restriction Flag',
'Max Medical Improvement DateID',
'Percent Impairment',
'Post Injury Weekly Wage',
'NCCI Job Code',
'Surgery Flag',
'Disability Status',
'SIC Group',
'NCCI BINatureOfLossDescription',
'Accident Source Code',
'Accident Type Group',
'HCPCS A Codes',
'HCPCS B Codes',
'HCPCS C Codes',
'HCPCS D Codes',
'HCPCS E Codes',
'HCPCS F Codes',
'HCPCS G Codes',
'HCPCS H Codes',
'HCPCS I Codes',
'HCPCS J Codes',
'HCPCS K Codes',
'HCPCS L Codes',
'HCPCS M Codes',
'HCPCS N Codes',
'HCPCS O Codes',
'HCPCS P Codes',
'HCPCS Q Codes',
'HCPCS R Codes',
'HCPCS S Codes',
'HCPCS T Codes',
'HCPCS U Codes',
'HCPCS V Codes',
'HCPCS W Codes',
'HCPCS X Codes',
'HCPCS Y Codes',
'HCPCS Z Codes',
'ICD Group 1',
'ICD Group 2',
'ICD Group 3',
'ICD Group 4',
'ICD Group 5',
'ICD Group 6',
'ICD Group 7',
'ICD Group 8',
'ICD Group 9',
'ICD Group 10',
'ICD Group 11',
'ICD Group 12',
'ICD Group 13',
'ICD Group 14',
'ICD Group 15',
'ICD Group 16',
'ICD Group 17',
'ICD Group 18',
'ICD Group 19',
'ICD Group 20',
'ICD Group 21',
'CPT Category - Anesthesia',
'CPT Category - Eval_Mgmt',
'CPT Category - Medicine',
'CPT Category - Path_Lab',
'CPT Category - Radiology',
'CPT Category - Surgery',
'NDC Class - Benzo',
'NDC Class - Misc (Zolpidem)',
'NDC Class - Muscle Relaxants',
'NDC Class - Stimulants', 'ClaimID'
], axis=1)

# %%
cleandf.head()
# Out:
#    Neurology Payment Flag  Neurosurgery Payment Flag  Dentist Payment Flag  \
# 0                   False                      False                 False
# 1                   False                      False                 False
# 2                   False                      False                 False
# 3                   False                      False                 False
# 4                   False                      False                 False
#
#    Orthopedic Surgery Payment Flag  Psychiatry Payment Flag  \
# 0                            False                    False
# 1                             True                    False
# 2                            False                    False
# 3                            False                    False
# 4                            False                    False
#
#    Hand Surgery Payment Flag  Optometrist Payment Flag  Podiatry Payment Flag  \
# 0                      False                     False                  False
# 1                      False                     False                   True
# 2                      False                      True                  False
# 3                      False                     False                  False
# 4                      False                     False                  False
#
#    Opiods Used
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False

# %%
#MACHINE LEARNING ALGORITHM

#We are going to use a classification model, Random Forest

X_train = cleandf.drop("Opiods Used", axis=1)
y_train = cleandf["Opiods Used"]
X_test  = cleandf.copy()

# %%
#Split the the original dataset to train then test using a sample of the original dataset

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
#RandomForest 
Classifier= RandomForestClassifier(n_estimators=200, random_state=10000)
Classifier.fit(X_train, y_train)
y_pred = Classifier.predict(X_test)

# %%
#Validate the accuracy of the model

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[22895   128]
#  [ 2442   234]]
#               precision    recall  f1-score   support
#
#        False       0.90      0.99      0.95     23023
#         True       0.65      0.09      0.15      2676
#
#    micro avg       0.90      0.90      0.90     25699
#    macro avg       0.78      0.54      0.55     25699
# weighted avg       0.88      0.90      0.86     25699
#
# 0.8999961087980077

# %%
#Our accuracy is around 90%
#this means out of 100 claimants the model could accurately predict opiod use (or not) 90% of the time

# %%
#Present results merged with input as df
X_test["Opiods Used"] = Classifier.predict(X_test)

# %%
X_test
# Out:
#         Neurology Payment Flag  Neurosurgery Payment Flag  \
# 42163                    False                      False
# 56906                    False                      False
# 84551                    False                      False
# 152884                   False                      False
# 136751                   False                      False
# 153162                   False                      False
# 14846                    False                      False
# 25128                    False                      False
# 74944                    False                      False
# 105915                   False                      False
# 40359                    False                      False
# 110128                   False                      False
# 145313                   False                      False
# 64203                    False                      False
# 121424                   False                      False
# 3524                     False                      False
# 154169                   False                      False
# 30581                    False                      False
# 90418                    False                      False
# 52910                    False                      False
# 43289                    False                      False
# 5187                     False                      False
# 125795                   False                      False
# 17538                    False                      False
# 75060                    False                      False
# 118609                   False                      False
# 26513                    False                      False
# 87931                    False                      False
# 101283                   False                      False
# 47542                    False                      False
# ...                        ...                        ...
# 39703                    False                      False
# 98663                    False                      False
# 89058                    False                      False
# 57019                    False                      False
# 44230                    False                      False
# 46087                    False                      False
# 92129                    False                      False
# 132071                   False                      False
# 72144                    False                      False
# 36400                    False                      False
# 29786                    False                      False
# 35539                    False                      False
# 104614                   False                      False
# 28004                    False                      False
# 83631                    False                      False
# 31485                    False                      False
# 100938                   False                      False
# 65820                    False                      False
# 110789                   False                       True
# 101177                   False                      False
# 37117                    False                      False
# 151475                   False                      False
# 36305                    False                      False
# 43222                    False                      False
# 43749                    False                      False
# 17002                    False                      False
# 48533                    False                      False
# 1792                     False                      False
# 123665                   False                      False
# 240                      False                      False
#
#         Dentist Payment Flag  Orthopedic Surgery Payment Flag  \
# 42163                  False                             True
# 56906                  False                            False
# 84551                  False                            False
# 152884                 False                            False
# 136751                 False                            False
# 153162                 False                            False
# 14846                  False                            False
# 25128                  False                             True
# 74944                  False                            False
# 105915                 False                            False
# 40359                  False                            False
# 110128                 False                            False
# 145313                 False                            False
# 64203                  False                            False
# 121424                 False                             True
# 3524                   False                            False
# 154169                 False                            False
# 30581                  False                            False
# 90418                  False                             True
# 52910                  False                             True
# 43289                  False                            False
# 5187                   False                            False
# 125795                 False                             True
# 17538                  False                            False
# 75060                  False                             True
# 118609                 False                            False
# 26513                  False                            False
# 87931                  False                            False
# 101283                 False                            False
# 47542                  False                            False
# ...                      ...                              ...
# 39703                  False                            False
# 98663                  False                            False
# 89058                  False                            False
# 57019                  False                            False
# 44230                  False                            False
# 46087                  False                            False
# 92129                  False                             True
# 132071                 False                             True
# 72144                  False                            False
# 36400                  False                            False
# 29786                  False                             True
# 35539                  False                             True
# 104614                 False                            False
# 28004                  False                            False
# 83631                  False                            False
# 31485                  False                             True
# 100938                 False                            False
# 65820                  False                            False
# 110789                 False                             True
# 101177                 False                            False
# 37117                  False                            False
# 151475                 False                            False
# 36305                  False                            False
# 43222                  False                            False
# 43749                  False                            False
# 17002                  False                            False
# 48533                  False                            False
# 1792                   False                            False
# 123665                 False                            False
# 240                    False                            False
#
#         Psychiatry Payment Flag  Hand Surgery Payment Flag  \
# 42163                     False                      False
# 56906                     False                      False
# 84551                     False                      False
# 152884                    False                      False
# 136751                    False                      False
# 153162                    False                      False
# 14846                     False                      False
# 25128                     False                      False
# 74944                     False                      False
# 105915                    False                      False
# 40359                     False                      False
# 110128                    False                      False
# 145313                    False                      False
# 64203                     False                       True
# 121424                    False                      False
# 3524                      False                      False
# 154169                    False                      False
# 30581                     False                      False
# 90418                     False                       True
# 52910                     False                      False
# 43289                     False                      False
# 5187                      False                      False
# 125795                    False                      False
# 17538                     False                      False
# 75060                     False                      False
# 118609                    False                      False
# 26513                     False                      False
# 87931                     False                      False
# 101283                    False                      False
# 47542                     False                      False
# ...                         ...                        ...
# 39703                     False                      False
# 98663                     False                      False
# 89058                     False                      False
# 57019                     False                      False
# 44230                     False                      False
# 46087                     False                      False
# 92129                     False                      False
# 132071                    False                      False
# 72144                     False                      False
# 36400                     False                      False
# 29786                     False                      False
# 35539                     False                      False
# 104614                    False                      False
# 28004                     False                      False
# 83631                     False                      False
# 31485                     False                      False
# 100938                    False                      False
# 65820                     False                      False
# 110789                    False                      False
# 101177                    False                      False
# 37117                     False                      False
# 151475                    False                      False
# 36305                     False                      False
# 43222                     False                      False
# 43749                     False                      False
# 17002                     False                      False
# 48533                     False                      False
# 1792                      False                      False
# 123665                    False                      False
# 240                       False                      False
#
#         Optometrist Payment Flag  Podiatry Payment Flag  Opiods Used
# 42163                      False                  False        False
# 56906                      False                  False        False
# 84551                      False                  False        False
# 152884                     False                  False        False
# 136751                     False                  False        False
# 153162                     False                  False        False
# 14846                      False                  False        False
# 25128                      False                  False        False
# 74944                      False                  False        False
# 105915                     False                  False        False
# 40359                      False                  False        False
# 110128                     False                  False        False
# 145313                     False                  False        False
# 64203                      False                  False        False
# 121424                     False                  False        False
# 3524                       False                  False        False
# 154169                     False                  False        False
# 30581                      False                  False        False
# 90418                      False                  False        False
# 52910                      False                  False        False
# 43289                      False                  False        False
# 5187                       False                  False        False
# 125795                     False                  False        False
# 17538                      False                  False        False
# 75060                      False                  False        False
# 118609                     False                  False        False
# 26513                      False                  False        False
# 87931                      False                  False        False
# 101283                     False                  False        False
# 47542                      False                  False        False
# ...                          ...                    ...          ...
# 39703                      False                  False        False
# 98663                      False                  False        False
# 89058                      False                  False        False
# 57019                      False                  False        False
# 44230                      False                  False        False
# 46087                      False                  False        False
# 92129                      False                  False        False
# 132071                     False                  False        False
# 72144                      False                  False        False
# 36400                      False                  False        False
# 29786                      False                  False        False
# 35539                      False                  False        False
# 104614                     False                  False        False
# 28004                      False                  False        False
# 83631                      False                   True        False
# 31485                      False                  False        False
# 100938                     False                  False        False
# 65820                      False                  False        False
# 110789                     False                  False         True
# 101177                     False                  False        False
# 37117                      False                  False        False
# 151475                     False                  False        False
# 36305                      False                  False        False
# 43222                      False                  False        False
# 43749                      False                  False        False
# 17002                      False                  False        False
# 48533                      False                  False        False
# 1792                       False                  False        False
# 123665                     False                  False        False
# 240                        False                  False        False
#
# [32124 rows x 9 columns]

# %%
#Generate output in .csv format 
X_test.to_csv("opiodusepredictionresults.csv")
